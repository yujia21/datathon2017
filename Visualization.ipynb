# %%
import numpy as np
import pandas as pd
# %matplotlib notebook

# %%
n = str(1) #chiller number
df = pd.read_csv("data/Chiller"+n+"_full.csv")
df.head()
# Out:
#    Unnamed: 0                   ts  ch1Watt  ch2Watt  ch3Watt     value1  \
# 0           0  2017-05-01 00:00:00      349        0      353  18.068238
# 1           1  2017-05-01 00:01:00      383        0      396  16.166991
# 2           2  2017-05-01 00:02:00      379        0      394  15.964052
# 3           3  2017-05-01 00:03:00      389        0      408  17.053528
# 4           4  2017-05-01 00:04:00     5748     4480     4942  18.559570
#
#       value2     value3     value4  conflowRate  conflowSpeed  evaflowRate  \
# 0  20.535583  23.376769  23.387453     0.000000      0.000000     0.000000
# 1  16.914672  22.565002  22.639772    35.284023      0.303604     0.000000
# 2  16.722413  22.372743  22.351379   144.330154      1.241898     0.000000
# 3  17.822570  22.265932  22.372743   195.770782      1.684522    10.812524
# 4  19.531554  22.415465  22.490235   214.631348      1.846809    77.101921
#
#    evaflowSpeed
# 0       0.00000
# 1       0.00000
# 2       0.00000
# ...

# %%
collist = [x for x in df['Power'].columns if 'ch1' in x]
df['Power'][collist].head()
# Out:
#                          ch1Watt  ch1Current  ch1Voltage  ch1PowerFactor  \
# ts
# 2017-05-01 00:00:35.405      349    1.907323       225.9           0.810
# 2017-05-01 00:01:18.981      383    2.117006       225.3           0.803
# 2017-05-01 00:02:26.277      379    2.113163       225.6           0.795
# 2017-05-01 00:03:00.949      389    2.170844       225.4           0.795
# 2017-05-01 00:04:04.133     5748   32.174643       225.0           0.794
#
#                          ch1Hz
# ts
# 2017-05-01 00:00:35.405  60.03
# 2017-05-01 00:01:18.981  59.89
# 2017-05-01 00:02:26.277  60.07
# 2017-05-01 00:03:00.949  60.02
# 2017-05-01 00:04:04.133  60.04

# %%
df['Temp'].head()
# Out:
#                          gatewayId  linkQuality   ain1   ain2   ain3   ain4  \
# ts
# 2017-05-01 00:00:12.687         18          191  13320  14244  15308  15312
# 2017-05-01 00:01:42.401         18          191  12608  12888  15004  15032
# 2017-05-01 00:02:30.223         18          191  12532  12816  14932  14924
# 2017-05-01 00:03:28.288         18          191  12940  13228  14892  14932
# 2017-05-01 00:04:19.164         18          191  13504  13868  14948  14976
#
#                          ain5  voltage1  voltage2  voltage3  voltage4  \
# ts
# 2017-05-01 00:00:12.687  2244  1.341431  1.434485  1.541638  1.542041
# 2017-05-01 00:01:42.401  2244  1.269727  1.297925  1.511023  1.513843
# 2017-05-01 00:02:30.223  2244  1.262073  1.290674  1.503772  1.502966
# 2017-05-01 00:03:28.288  2244  1.303162  1.332165  1.499744  1.503772
# 2017-05-01 00:04:19.164  2244  1.359961  1.396619  1.505383  1.508203
#
#                          voltage5     value1     value2     value3     value4
# ...

# %%
#import datetime
# use .loc[datetime.date(2017,5,1):datetime.date(2017,5,3)] to choose dates

df_clean = df['Power'].drop(df['Power'].ch3Current.argmax())
df_clean[['ch'+str(i+1)+'Watt' for i in range(1)]].plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
df['Temp'][['value'+str(i+1) for i in range(4)]].plot()
# Out:
# <img src="data:image/png;base64,...">

# %%
df['ConFlow'][['flowRate']].plot(title="ConFlow")
df['EvaFlow'][['flowRate']].plot(title="EvaFlow")
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
