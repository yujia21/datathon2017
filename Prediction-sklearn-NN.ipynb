# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib notebook

# %%
n = str(1) #chiller number
df = pd.read_csv("data/Chiller"+n+"_full.csv")
df.index = pd.to_datetime(df['ts'])
df.drop('ts', axis=1, inplace=True)
df.head()
# Out:
#                      ch1Watt  ch2Watt  ch3Watt     value1     value2  \
# ts
# 2017-05-01 00:00:00    349.0      0.0    353.0  18.068238  20.535583
# 2017-05-01 00:01:00    383.0      0.0    396.0  16.166991  16.914672
# 2017-05-01 00:02:00    379.0      0.0    394.0  15.964052  16.722413
# 2017-05-01 00:03:00    389.0      0.0    408.0  17.053528  17.822570
# 2017-05-01 00:04:00   5748.0   4480.0   4942.0  18.559570  19.531554
#
#                         value3     value4  conflowRate  conflowSpeed  \
# ts
# 2017-05-01 00:00:00  23.376769  23.387453     0.000000      0.000000
# 2017-05-01 00:01:00  22.565002  22.639772    35.284023      0.303604
# 2017-05-01 00:02:00  22.372743  22.351379   144.330154      1.241898
# 2017-05-01 00:03:00  22.265932  22.372743   195.770782      1.684522
# 2017-05-01 00:04:00  22.415465  22.490235   214.631348      1.846809
#
#                      evaflowRate  evaflowSpeed
# ts
# 2017-05-01 00:00:00     0.000000       0.00000
# 2017-05-01 00:01:00     0.000000       0.00000
# 2017-05-01 00:02:00     0.000000       0.00000
# 2017-05-01 00:03:00    10.812524       0.16108
# 2017-05-01 00:04:00    77.101921       1.14863

# %%
df['deltaT12'] = df['value2']-df['value1']
df['totalWatt'] = df.apply(lambda row: row['ch1Watt']+row['ch2Watt']+row['ch3Watt'], axis=1)
df.drop(['ch1Watt', 'ch2Watt', 'ch3Watt'], inplace=True, axis=1)
df=df[['value1','value2','value3','value4','conflowRate','conflowSpeed','evaflowRate','evaflowSpeed','deltaT12','totalWatt']]
df.head()
# Out:
#                         value1     value2     value3     value4  conflowRate  \
# ts
# 2017-05-01 00:00:00  18.068238  20.535583  23.376769  23.387453     0.000000
# 2017-05-01 00:01:00  16.166991  16.914672  22.565002  22.639772    35.284023
# 2017-05-01 00:02:00  15.964052  16.722413  22.372743  22.351379   144.330154
# 2017-05-01 00:03:00  17.053528  17.822570  22.265932  22.372743   195.770782
# 2017-05-01 00:04:00  18.559570  19.531554  22.415465  22.490235   214.631348
#
#                      conflowSpeed  evaflowRate  evaflowSpeed  deltaT12  \
# ts
# 2017-05-01 00:00:00      0.000000     0.000000       0.00000  2.467346
# 2017-05-01 00:01:00      0.303604     0.000000       0.00000  0.747681
# 2017-05-01 00:02:00      1.241898     0.000000       0.00000  0.758361
# 2017-05-01 00:03:00      1.684522    10.812524       0.16108  0.769042
# 2017-05-01 00:04:00      1.846809    77.101921       1.14863  0.971984
#
#                      totalWatt
# ts
# 2017-05-01 00:00:00      702.0
# 2017-05-01 00:01:00      779.0
# 2017-05-01 00:02:00      773.0
# 2017-05-01 00:03:00      797.0
# 2017-05-01 00:04:00    15170.0

# %%
df['H']=df['deltaT12']*df['evaflowRate']
df.head()
# Out:
#                         value1     value2     value3     value4  conflowRate  \
# ts
# 2017-05-01 00:00:00  18.068238  20.535583  23.376769  23.387453     0.000000
# 2017-05-01 00:01:00  16.166991  16.914672  22.565002  22.639772    35.284023
# 2017-05-01 00:02:00  15.964052  16.722413  22.372743  22.351379   144.330154
# 2017-05-01 00:03:00  17.053528  17.822570  22.265932  22.372743   195.770782
# 2017-05-01 00:04:00  18.559570  19.531554  22.415465  22.490235   214.631348
#
#                      conflowSpeed  evaflowRate  evaflowSpeed  deltaT12  \
# ts
# 2017-05-01 00:00:00      0.000000     0.000000       0.00000  2.467346
# 2017-05-01 00:01:00      0.303604     0.000000       0.00000  0.747681
# 2017-05-01 00:02:00      1.241898     0.000000       0.00000  0.758361
# 2017-05-01 00:03:00      1.684522    10.812524       0.16108  0.769042
# 2017-05-01 00:04:00      1.846809    77.101921       1.14863  0.971984
#
#                      totalWatt          H
# ts
# 2017-05-01 00:00:00      702.0   0.000000
# 2017-05-01 00:01:00      779.0   0.000000
# 2017-05-01 00:02:00      773.0   0.000000
# 2017-05-01 00:03:00      797.0   8.315282
# 2017-05-01 00:04:00    15170.0  74.941855

# %%
df[['value1', 'evaflowRate', 'deltaT12','H','totalWatt']].describe()
# Out:
#               value1    evaflowRate       deltaT12              H  \
# count  258731.000000  258731.000000  258731.000000  258731.000000
# mean       13.454318      40.321105       4.037717      99.416837
# std         3.427558      82.491036       3.614330     240.321854
# min         0.000000       0.000000     -38.206486    -129.271799
# 25%        10.997316       0.000000       1.196288       0.000000
# 50%        12.973329       0.000000       3.257752       0.000000
# 75%        16.444704      14.330884       6.579590       0.000000
# max        69.989324     233.577560      53.939825    1131.655275
#
#            totalWatt
# count  258731.000000
# mean    24990.240839
# std     58619.205854
# min       203.000000
# 25%       693.000000
# 50%       703.000000
# 75%       717.000000
# max    227587.000000

# %%
X = df[(df['evaflowRate']>125)&(df['totalWatt']>20000)][['value1', 'evaflowRate', 'deltaT12','H']].as_matrix()
y = df[(df['evaflowRate']>125)&(df['totalWatt']>20000)][['totalWatt']].as_matrix().sum(axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()  
scaler.fit(X_train)
X_train = scaler.transform(X_train)  
X_test = scaler.transform(X_test)  
X_full = scaler.transform(X)

# %%
from sklearn.neural_network import MLPRegressor
n_layer=400
regr = MLPRegressor(hidden_layer_sizes=(n_layer, n_layer, n_layer), max_iter=500, verbose=True, random_state=22)
regr.fit(X_train, y_train)

y_pred = regr.predict(X_full)
y_pred_test = regr.predict(X_test)
# Out:
# Iteration 1, loss = 7622004931.95213223
# Iteration 2, loss = 533834598.86549449
# Iteration 3, loss = 223315044.86072871
# Iteration 4, loss = 187911807.25416255
# Iteration 5, loss = 179161898.02861196
# Iteration 6, loss = 175833969.92142823
# Iteration 7, loss = 173773473.34564787
# Iteration 8, loss = 172076545.50129750
# Iteration 9, loss = 170156955.46484229
# Iteration 10, loss = 166644894.01364905
# Iteration 11, loss = 161765992.82541302
# Iteration 12, loss = 154418421.38443375
# Iteration 13, loss = 145670094.36865762
# Iteration 14, loss = 134885503.10997388
# Iteration 15, loss = 123787166.46939576
# Iteration 16, loss = 115136343.61151077
# Iteration 17, loss = 109376084.00553387
# Iteration 18, loss = 105475882.84887378
# Iteration 19, loss = 102534575.31312145
# Iteration 20, loss = 100059630.84251875
# Iteration 21, loss = 97887716.33723255
# Iteration 22, loss = 95701636.03645736
# Iteration 23, loss = 94053958.23381944
# Iteration 24, loss = 92604386.42597540
# Iteration 25, loss = 91142317.46605833
# Iteration 26, loss = 89947568.24014355
# Iteration 27, loss = 88709457.94236940
# Iteration 28, loss = 87403707.18529108
# Iteration 29, loss = 86429476.45864473
# Iteration 30, loss = 85616899.97350758
# Iteration 31, loss = 84831673.86607626
# Iteration 32, loss = 83901325.40007743
# Iteration 33, loss = 83554231.26014315
# Iteration 34, loss = 82756496.29973578
# Iteration 35, loss = 82125911.33774181
# Iteration 36, loss = 81234396.84402297
# Iteration 37, loss = 80675194.34189394
# Iteration 38, loss = 80105270.88047035
# Iteration 39, loss = 79423378.99017657
# Iteration 40, loss = 78791399.82613046
# Iteration 41, loss = 78385270.36553980
# Iteration 42, loss = 77890130.30387922
# Iteration 43, loss = 77376399.67432792
# Iteration 44, loss = 77057245.80426773
# Iteration 45, loss = 76528930.85537690
# Iteration 46, loss = 76124147.43919472
# Iteration 47, loss = 75837041.71851529
# Iteration 48, loss = 75527035.20780247
# Iteration 49, loss = 75082424.08911192
# Iteration 50, loss = 74437491.42269756
# Iteration 51, loss = 74121710.11133826
# Iteration 52, loss = 73998738.00572646
# Iteration 53, loss = 73893625.03563507
# Iteration 54, loss = 73074365.22509514
# Iteration 55, loss = 73311280.08689739
# Iteration 56, loss = 72495035.56778935
# Iteration 57, loss = 72496649.42375730
# Iteration 58, loss = 72226920.07155055
# Iteration 59, loss = 71978484.98586331
# Iteration 60, loss = 71918566.40098917
# Iteration 61, loss = 71654068.05003832
# Iteration 62, loss = 71280695.30777512
# Iteration 63, loss = 70802869.81545302
# Iteration 64, loss = 70712923.66309129
# Iteration 65, loss = 70445121.28120339
# Iteration 66, loss = 70908074.92934501
# Iteration 67, loss = 69917487.70836750
# Iteration 68, loss = 69724039.32178997
# Iteration 69, loss = 70187981.00656110
# Iteration 70, loss = 69386322.76780690
# Iteration 71, loss = 69035870.11111011
# Iteration 72, loss = 69174854.84780633
# Iteration 73, loss = 68995802.42697901
# Iteration 74, loss = 69132878.82185102
# Iteration 75, loss = 69197059.57253347
# Iteration 76, loss = 68621352.22298928
# Iteration 77, loss = 68348743.05289578
# Iteration 78, loss = 67994587.04680863
# Iteration 79, loss = 67791092.61277643
# Iteration 80, loss = 67567208.89381845
# Iteration 81, loss = 67398412.18759874
# Iteration 82, loss = 67366490.52598184
# Iteration 83, loss = 67394616.97491144
# Iteration 84, loss = 66873335.45839219
# Iteration 85, loss = 66960543.72144963
# Iteration 86, loss = 66801191.40508000
# Iteration 87, loss = 66765315.66205818
# Iteration 88, loss = 66359424.03753044
# Iteration 89, loss = 66269624.61476583
# Iteration 90, loss = 67126190.67232360
# Iteration 91, loss = 66177991.80569991
# Iteration 92, loss = 66065062.57559291
# Iteration 93, loss = 66015894.07580735
# Iteration 94, loss = 65892242.48797600
# Iteration 95, loss = 65815142.14033575
# Iteration 96, loss = 65830170.06761061
# Iteration 97, loss = 65665888.95329686
# Iteration 98, loss = 65323587.45868967
# Iteration 99, loss = 65370734.26106866
# Iteration 100, loss = 65044538.97526782
# Iteration 101, loss = 65467992.67886871
# Iteration 102, loss = 64724369.09189692
# Iteration 103, loss = 64756511.76869827
# Iteration 104, loss = 64580892.08109694
# Iteration 105, loss = 64721479.03897710
# Iteration 106, loss = 64751178.07737131
# Iteration 107, loss = 64654145.43823936
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.

# %%
y_df = pd.DataFrame(np.concatenate((y.reshape((y.shape[0],1)), y_pred.reshape((y_pred.shape[0],1))), axis=1))
y_df.columns=['y_true', 'y_pred']
y_df.plot(title='Randomized train and test set')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y_test_df = pd.DataFrame(np.concatenate((y_test.reshape((y_test.shape[0],1)), y_pred_test.reshape((y_pred_test.shape[0],1))), axis=1))
y_test_df.columns=['y_true', 'y_pred']
y_test_df.plot(title='Test set')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pd.DataFrame(regr.coefs_[0].T).describe()
# Out:
#                 0           1           2           3
# count  200.000000  200.000000  200.000000  200.000000
# mean    -0.145959   -0.006321    0.152002    0.057186
# std      0.751389    0.505253    0.294356    0.310677
# min     -4.347312   -2.121079   -1.946765   -1.996148
# 25%     -0.086872   -0.075844   -0.003942   -0.117839
# 50%     -0.059174   -0.034094    0.142225    0.019024
# 75%     -0.011405    0.054227    0.296269    0.223920
# max      1.735173    1.849093    0.976616    0.983919

# %%
from sklearn.metrics import mean_absolute_error as mae
print(mae(y_test, y_pred_test))
y_test_df['absolute error'] = abs(y_test_df['y_true'] - y_test_df['y_pred'])
y_test_df['relative error'] = abs(y_test_df['y_true'] - y_test_df['y_pred'])/y_test_df['y_true']
y_test_df.describe()
# Out:
# 7310.15423371
#               y_true         y_pred  absolute error  relative error
# count    4275.000000    4275.000000     4275.000000    4.275000e+03
# mean   146267.716374  145354.434887     7310.154234    5.612559e-02
# std     52540.682852   51638.487637     8949.950588    6.868984e-02
# min     27531.000000   31668.501897        0.022387    3.420942e-07
# 25%    103423.000000  107010.008151     1931.228518    1.328897e-02
# 50%    171021.000000  164268.819923     4299.907883    3.230370e-02
# 75%    189608.000000  187295.580517     8870.393832    7.286041e-02
# max    223436.000000  217293.215918    74481.970971    6.103279e-01

# %%
T1_min=np.array(df[(df['evaflowRate']>125)&(df['totalWatt']>25000)][['value1', 'evaflowRate']].describe().loc['min'])[0]
T1_max=np.array(df[(df['evaflowRate']>125)&(df['totalWatt']>25000)][['value1', 'evaflowRate']].describe().loc['max'])[0]
F_min=np.array(df[(df['evaflowRate']>125)&(df['totalWatt']>25000)][['value1', 'evaflowRate']].describe().loc['min'])[1]
F_max=np.array(df[(df['evaflowRate']>125)&(df['totalWatt']>25000)][['value1', 'evaflowRate']].describe().loc['max'])[1]
H_mean=np.array(df[(df['evaflowRate']>125)&(df['totalWatt']>25000)][['H']].describe().loc['mean'])[0]
df[(df['evaflowRate']>125)&(df['totalWatt']>25000)][['value1', 'evaflowRate','H']].describe()
# Out:
#              value1   evaflowRate             H
# count  42739.000000  42739.000000  42739.000000
# mean       8.665844    222.036617    608.142217
# std        1.208204      4.354516    198.732176
# min        4.652710    127.265194    -45.377086
# 25%        8.188171    221.005180    492.459946
# 50%        8.615417    221.506607    673.339842
# 75%        9.117430    224.710419    742.721023
# max       23.814699    233.577560   1131.655275

# %%
T1=np.arange(np.floor(T1_min), np.ceil(T1_max)+5, 0.5)
F=np.arange(175, np.ceil(F_max), 0.5) #np.floor(F_min)

# %%
#H is just deltaT12*F because optimizing ignores constants
H=H_mean
def COP(H,T1,F_full):
    n = len(T1)
    m = len(F_full)
    P_full=np.zeros((n,m))
    i=0
    for F in F_full:
        X=np.array([T1,F*np.ones(n),(H/F)*np.ones(n),H*np.ones(n)]).T
        P = regr.predict(scaler.transform(X))
        P_full[:,i]=P
        i+=1
    assert(P_full.shape == (n,m))
    return H/P_full,P_full
COP_T,P_T = COP(H,T1,F)

# %%
plt.plot(T1,COP_T)
plt.xlabel('T1')
plt.ylabel('COP')
plt.title('COP vs T1 for H = '+str(H)+' and F = '+str(F[0])+' to F = '+str(F[-1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-284-0d0c3c7e682a> in <module>()
#       2 plt.xlabel('T1')
#       3 plt.ylabel('COP')
# ----> 4 plt.title('COP vs T1 for H = '+str(H)+' and F = '+str(F[0])+' to F = '+str(F[-1]))
#
# TypeError: 'str' object is not callable

# %%
plt.title('COP vs F for H = '+str(H)+' and T1 = '+str(T1[0])+' to T1 = '+str(T1[-1]))
plt.plot(F,COP_T.T)
plt.xlabel('F')
plt.ylabel('COP')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-285-dd52507e1604> in <module>()
# ----> 1 plt.title('COP vs F for H = '+str(H)+' and T1 = '+str(T1[0])+' to T1 = '+str(T1[-1]))
#       2 plt.plot(F,COP_T.T)
#       3 plt.xlabel('F')
#       4 plt.ylabel('COP')
#
# TypeError: 'str' object is not callable

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
F_full=np.ones((len(T1),1)).dot(F.reshape(1,len(F)))
T1_full=np.ones((len(F),1)).dot(T1.reshape(1,len(T1))).T
#surf=ax.plot_surface(F_full, T1_full, COP_T,cmap=cm.coolwarm,linewidth=0, antialiased=False)
#fig.colorbar(surf,shrink=0.5, aspect=5)
surf=ax.plot_wireframe(F_full, T1_full, COP_T)
ax.set_xlabel('FlowRate')
ax.set_ylabel('T1')
ax.set_zlabel('COP')
ax.set_title('COP for H = '+str(H_mean))

# %%
#100,100,100: 68163886.94090495,7434.29141922
#200,200,200: 66024496.13697716,7195.521646
#300,300,300: 70120189.58196577,7490.62158718
#400,400,400: 66318930.86602330,7428.63799163
