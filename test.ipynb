# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
file1 = "1513221037067-May Chiller1 pm"
df1 = pd.read_csv("data/"+file1+".csv")
df1.columns
# Out:
# Index([u'ts', u'gatewayId', u'linkQuality', u'ieee', u'receivedSync',
#        u'randTime', u'ch1Watt', u'ch2Watt', u'ch3Watt',
#        u'totalPositiveWattHour', u'totalNegativeWattHour', u'ch1Current',
#        u'ch2Current', u'ch3Current', u'ch1Voltage', u'ch2Voltage',
#        u'ch3Voltage', u'ch1PowerFactor', u'ch2PowerFactor', u'ch3PowerFactor',
#        u'voltage12', u'voltage23', u'voltage31', u'ch1Hz', u'ch2Hz', u'ch3Hz',
#        u'i1THD', u'i2THD', u'i3THD', u'v1THD', u'v2THD', u'v3THD'],
#       dtype='object')

# %%
df1.head()
# Out:
#                         ts  gatewayId  linkQuality    ieee  receivedSync  \
# 0  2017-05-01 00:00:35.405         18          181  d5dddb           NaN
# 1  2017-05-01 00:01:18.981         18          181  d5dddb           NaN
# 2  2017-05-01 00:02:26.277         18          181  d5dddb           NaN
# 3  2017-05-01 00:03:00.949         18          181  d5dddb           NaN
# 4  2017-05-01 00:04:04.133         18          181  d5dddb           NaN
#
#    randTime  ch1Watt  ch2Watt  ch3Watt  totalPositiveWattHour  ...    \
# 0       NaN      349        0      353             27545200.0  ...
# 1       NaN      383        0      396             27545200.0  ...
# 2       NaN      379        0      394             27545200.0  ...
# 3       NaN      389        0      408             27545200.0  ...
# 4       NaN     5748     4480     4942             27545300.0  ...
#
#    voltage31  ch1Hz  ch2Hz  ch3Hz  i1THD  i2THD  i3THD  v1THD  v2THD  v3THD
# 0      390.4  60.03  60.03  60.03   13.7    0.0    8.9    1.1    1.0    1.2
# 1      389.1  59.89  59.89  59.89    8.2    0.0   10.3    1.4    1.2    1.6
# 2      389.6  60.07  60.07  60.07    6.0    0.0    6.1    1.4    1.2    1.4
# 3      389.7  60.02  60.02  60.02    7.0    0.0    7.8    1.4    1.3    1.3
# 4      389.1  60.04  60.04  60.04   74.3   83.8   78.4    1.7    1.5    1.7
#
# [5 rows x 32 columns]

# %%
thing1='Voltage'
df1[['ch'+str(i+1)+thing1 for i in range(1)]].plot()

# %%
file2 = "1513219320860-May Chiller1 temp"
df2 = pd.read_csv("data/"+file2+".csv")
df2.columns
# Out:
# Index([u'ts', u'gatewayId', u'linkQuality', u'ieee', u'receivedSync',
#        u'randTime', u'ain1', u'ain2', u'ain3', u'ain4', u'ain5', u'voltage1',
#        u'voltage2', u'voltage3', u'voltage4', u'voltage5', u'value1',
#        u'value2', u'value3', u'value4', u'value5'],
#       dtype='object')

# %%
thing='voltage'
df2[[thing+str(i+1) for i in range(5)]].plot()
